# %%
import pandas as pd

# %% [markdown]
# I have an excel file as dataset whose each row is some short of text. You can take whatever you wish.

# %%
#parsing the excel file as pandas dataframe
document = pd.read_excel("C:/Users/HP/Documents/sample_resumes.xlsx")
documen = document.head(3)

# %%
documen
# Out:
#                                             raw_text
# 0                                                ...
# 1                                                ...
# 2  BANOTHU KALYAN VARMA NAIK 1-93 MAHALAKSHMIPURA...

# %%
ser_text = documen['raw_text']

# %%
ser_text = list(ser_text)

# %%
ser_text
# Out:
# ['                                                 N AT ION A L  IN ST IT UT E OF   TE CH N O LOG Y                     T IRU CH IR AP P AL L I                        B H A R A T H   K U M A R   J   M al e,   I n d i an ,   2 0   y ear s   1 / 1 0   p i l l ay ar   k o v i l   S t r ee t ,   i n j am b ak k am     C h en n ai - 6 0 0 1 1 5          E m ai l   :   b h ar at h _ k u m a r _ j @ h o t m ai l . co m     PERSONAL DETAILS         Fathers Name        :  Jothi Raja K    Date of Birth          : 21th October 1993    Languages Known : English, Tamil, Hindi, Telugu                              EDUCATION     B.Tech     Semester    GPA     Class XII   (CBSE)   Class X    (MATRIC)   Civil Engineering      I   6.0      II   5.7      III   5.5      IV   5.82      V   5.9   VI    6.0   VII   VIII   5.9   6.0     2011   Vani  Vidyalaya  Senior  Secondary  And  Junior  College,  Chennai    56.8%     2009   Sri  Krishnaswamy  Matriculation  Higher  Secondary  School, Chennai    74.2%   
# ...

# %%
text = ' '.join(ser_text)

# %%
#finally making a text corpora
text
# Out:
# '                                                 N AT ION A L  IN ST IT UT E OF   TE CH N O LOG Y                     T IRU CH IR AP P AL L I                        B H A R A T H   K U M A R   J   M al e,   I n d i an ,   2 0   y ear s   1 / 1 0   p i l l ay ar   k o v i l   S t r ee t ,   i n j am b ak k am     C h en n ai - 6 0 0 1 1 5          E m ai l   :   b h ar at h _ k u m a r _ j @ h o t m ai l . co m     PERSONAL DETAILS         Fathers Name        :  Jothi Raja K    Date of Birth          : 21th October 1993    Languages Known : English, Tamil, Hindi, Telugu                              EDUCATION     B.Tech     Semester    GPA     Class XII   (CBSE)   Class X    (MATRIC)   Civil Engineering      I   6.0      II   5.7      III   5.5      IV   5.82      V   5.9   VI    6.0   VII   VIII   5.9   6.0     2011   Vani  Vidyalaya  Senior  Secondary  And  Junior  College,  Chennai    56.8%     2009   Sri  Krishnaswamy  Matriculation  Higher  Secondary  School, Chennai    74.2%   P
# ...

# %%
#import gensim library
from gensim import corpora
# Out:
# C:\Users\HP\Anaconda3\lib\site-packages\gensim-2.1.0-py3.6-win-amd64.egg\gensim\utils.py:860: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
#removing stopwords using customized code
stoplist = set('for a of the and to in'.split())
texts = [[word for word in document.lower().split() if word not in stoplist]
         for document in ser_text]

# %%
# making dictionary from text corpus
dictionary = corpora.Dictionary(texts)

# %%
print(dictionary)
# Out:
# Dictionary(658 unique tokens: ['n', 'at', 'ion', 'l', 'st']...)

# %%
#print the token for each unique word
print(dictionary.token2id)
# Out:
# {'n': 0, 'at': 1, 'ion': 2, 'l': 3, 'st': 4, 'it': 5, 'ut': 6, 'e': 7, 'te': 8, 'ch': 9, 'o': 10, 'log': 11, 'y': 12, 't': 13, 'iru': 14, 'ir': 15, 'ap': 16, 'p': 17, 'al': 18, 'i': 19, 'b': 20, 'h': 21, 'r': 22, 'k': 23, 'u': 24, 'm': 25, 'j': 26, 'e,': 27, 'd': 28, 'an': 29, ',': 30, '2': 31, '0': 32, 'ear': 33, 's': 34, '1': 35, '/': 36, 'ay': 37, 'ar': 38, 'v': 39, 'ee': 40, 'am': 41, 'ak': 42, 'c': 43, 'en': 44, 'ai': 45, '-': 46, '6': 47, '5': 48, ':': 49, '_': 50, '@': 51, '.': 52, 'co': 53, 'personal': 54, 'details': 55, 'fathers': 56, 'name': 57, 'jothi': 58, 'raja': 59, 'date': 60, 'birth': 61, '21th': 62, 'october': 63, '1993': 64, 'languages': 65, 'known': 66, 'english,': 67, 'tamil,': 68, 'hindi,': 69, 'telugu': 70, 'education': 71, 'b.tech': 72, 'semester': 73, 'gpa': 74, 'class': 75, 'xii': 76, '(cbse)': 77, 'x': 78, '(matric)': 79, 'civil': 80, 'engineering': 81, '6.0': 82, 'ii': 83, '5.7': 84, 'iii': 85, '5.5': 86, 'iv': 87, '5.82': 88, '5.9': 89, 'vi': 90, 'vii': 91
# ...

# %%
#making bag of words
corpus = [dictionary.doc2bow(text) for text in texts]
 # store to disk, for later use
for c in corpus:
    print(c)
# Out:
# [(0, 5), (1, 5), (2, 1), (3, 7), (4, 1), (5, 1), (6, 1), (7, 2), (8, 1), (9, 2), (10, 3), (11, 1), (12, 2), (13, 5), (14, 1), (15, 1), (16, 1), (17, 2), (18, 2), (19, 7), (20, 3), (21, 6), (22, 4), (23, 5), (24, 2), (25, 6), (26, 3), (27, 1), (28, 1), (29, 1), (30, 4), (31, 1), (32, 4), (33, 1), (34, 2), (35, 4), (36, 1), (37, 1), (38, 2), (39, 2), (40, 1), (41, 2), (42, 1), (43, 2), (44, 1), (45, 3), (46, 1), (47, 1), (48, 1), (49, 10), (50, 2), (51, 1), (52, 1), (53, 1), (54, 2), (55, 1), (56, 1), (57, 1), (58, 1), (59, 1), (60, 1), (61, 1), (62, 1), (63, 1), (64, 1), (65, 2), (66, 1), (67, 1), (68, 1), (69, 1), (70, 1), (71, 1), (72, 1), (73, 1), (74, 1), (75, 2), (76, 1), (77, 1), (78, 1), (79, 1), (80, 1), (81, 1), (82, 3), (83, 1), (84, 1), (85, 1), (86, 1), (87, 1), (88, 1), (89, 2), (90, 1), (91, 1), (92, 1), (93, 1), (94, 1), (95, 1), (96, 1), (97, 2), (98, 1), (99, 1), (100, 3), (101, 1), (102, 1), (103, 1), (104, 1), (105, 1), (106, 1), (107, 1), (108, 1), (109, 1), (110, 
# ...

# %%
#making tf-idf from the corpus
from gensim import models,similarities

# %%
 tfidf = models.TfidfModel(corpus)

# %%
corpus_tfidf = tfidf[corpus]
for doc in corpus_tfidf:
    print(doc)
# Out:
# [(0, 0.13705061117171088), (2, 0.027410122234342176), (3, 0.19187085564039524), (4, 0.027410122234342176), (6, 0.027410122234342176), (7, 0.05482024446868435), (8, 0.027410122234342176), (9, 0.05482024446868435), (10, 0.08223036670302654), (11, 0.027410122234342176), (12, 0.05482024446868435), (13, 0.13705061117171088), (14, 0.027410122234342176), (15, 0.027410122234342176), (16, 0.027410122234342176), (17, 0.05482024446868435), (18, 0.05482024446868435), (21, 0.16446073340605308), (22, 0.1096404889373687), (23, 0.13705061117171088), (24, 0.05482024446868435), (25, 0.16446073340605308), (26, 0.08223036670302654), (27, 0.027410122234342176), (28, 0.027410122234342176), (30, 0.1096404889373687), (32, 0.1096404889373687), (33, 0.027410122234342176), (34, 0.05482024446868435), (36, 0.027410122234342176), (37, 0.027410122234342176), (38, 0.05482024446868435), (39, 0.05482024446868435), (40, 0.027410122234342176), (41, 0.05482024446868435), (42, 0.027410122234342176), (43, 0.05482024446868
# ...

# %%
gensim.parsing.preprocessing.preprocess_documents(ser_text)
# Out:
# [['ion',
#   'log',
#   'iru',
#   'ear',
#   'person',
#   'detail',
#   'father',
#   'jothi',
#   'raja',
#   'date',
#   'birth',
#   'octob',
#   'languag',
#   'known',
#   'english',
#   'tamil',
#   'hindi',
#   'telugu',
#   'educ',
#   'tech',
#   'semest',
#   'gpa',
#   'class',
#   'xii',
#   'cbse',
#   'class',
#   'matric',
#   'civil',
#   'engin',
#   'iii',
#   'vii',
#   'viii',
#   'vani',
#   'vidyalaya',
#   'senior',
#   'secondari',
#   'junior',
#   'colleg',
#   'chennai',
#   'sri',
#   'krishnaswami',
#   'matricul',
#   'higher',
#   'secondari',
#   'school',
#   'chennai',
#   'project',
#   'work',
#   'train',
#   'plant',
#   'train',
#   'cmrl',
#   'chennai',
#   'juli',
#   'exposur',
#   'ground',
#   'tunnel',
#   'station',
#   'construct',
#   'new',
#   'rail',
#   'base',
#   'rapid',
#   'transport',
#   'plant',
#   'train',
#   'juli',
#   'lafarg',
#   'aggreg',
#   'concret',
#   'manufactur',
#   'process',
#   'transport',
# ...

# %%
import gensim
